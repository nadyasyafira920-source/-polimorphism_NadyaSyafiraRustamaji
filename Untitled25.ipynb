# %% [markdown]
# <a href="https://colab.research.google.com/github/nadyasyafira920-source/-polimorphism_NadyaSyafiraRustamaji/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = input ("masukkan nama :")
umur = input ("masukkan umur ;")
alamat = input ("masukkan alamat")

print ("===================")
print ("Biodata Mahasiswa")
print ("===================")
print ("Nama : ", nama)
print ("Umur :", umur)
print ("Alamat :", alamat)
# Out:
# masukkan nama :Nadya
# masukkan umur ;20
# masukkan alamatJember
# ===================
# Biodata Mahasiswa
# ===================
# Nama :  Nadya
# Umur : 20
# Alamat : Jember

# %%
sisi = float (input ("masukkan sisi :"))
luas = sisi*sisi
print ("Luas Persegi : ", luas)
# Out:
# masukkan sisi :10
# Luas Persegi :  100.0

# %%
phi = 3.14
r = float(input("Masukkan jari-jari : "))
luas = phi * r * r
print("Luas Lingkaran =", luas)
# Out:
# Masukkan jari-jari : 14
# Luas Lingkaran = 615.44

# %%
celcius = float(input("Masukkan suhu Celcius : "))
fahrenheit = (9/5 * celcius) + 32
reamur = 4/5 * celcius
kelvin = celcius + 273

print("Fahrenheit :", fahrenheit)
print("Reamur     :", reamur)
print("Kelvin     :", kelvin)
# Out:
# Masukkan suhu Celcius : 30
# Fahrenheit : 86.0
# Reamur     : 24.0
# Kelvin     : 303.0
